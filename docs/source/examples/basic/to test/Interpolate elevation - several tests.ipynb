# %%
# Interpolate an elevation profile given a set of distances on the map and associated elevations
#### O. Kaufmann, march-april 2017

# %%
% matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bisect import bisect_left
from scipy.interpolate import PPoly, PchipInterpolator
from scipy.integrate import quad

# %% [markdown]
# ### create a list of lists, each list in the list is [projected distance, elevation] of a single point alon the profile

# %%
known_points=[[0,284],[58,280],[152,275],[217,270],[228,267],[305,265],[340,260], [374,255], [397,250], [417,245], [459, 240], [484, 245], [539, 250], [687, 245]]

# %% [markdown]
# ### convert it to a dataframe

# %%
df = pd.DataFrame(known_points, columns = ['Distance', 'Elevation'])
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Distance</th>
#       <th>Elevation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>284</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>58</td>
#       <td>280</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>152</td>
#       <td>275</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>217</td>
#       <td>270</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>228</td>
#       <td>267</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>305</td>
#       <td>265</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>340</td>
#       <td>260</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>374</td>
#       <td>255</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>397</td>
#       <td>250</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>417</td>
#       <td>245</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>459</td>
#       <td>240</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>484</td>
#       <td>245</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>539</td>
#       <td>250</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>687</td>
#       <td>245</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
plt.plot(df['Distance'], df['Elevation'], '-k')

# %%
tirs = []
geophones_x = np.arange(5,475,5)
tirs_x = np.arange(2.5,522.5,20.)

# %%
for x in tirs_x:
    if not x in df['Distance']: 
        tirs.append([x, np.nan])

# %%
tirs
# Out:
# [[22.5, nan],
#  [42.5, nan],
#  [62.5, nan],
#  [82.5, nan],
#  [102.5, nan],
#  [122.5, nan],
#  [142.5, nan],
#  [162.5, nan],
#  [182.5, nan],
#  [202.5, nan],
#  [222.5, nan],
#  [242.5, nan],
#  [262.5, nan],
#  [282.5, nan],
#  [302.5, nan],
#  [322.5, nan],
#  [342.5, nan],
#  [362.5, nan],
#  [382.5, nan],
#  [402.5, nan],
#  [422.5, nan],
#  [442.5, nan],
#  [462.5, nan],
#  [482.5, nan],
#  [502.5, nan]]

# %%
df_tirs = pd.DataFrame(tirs, columns = ['Distance', 'Elevation'])
#df_tirs.set_index('Distance', inplace=True)
df_tirs
# Out:
#     Distance  Elevation
# 0       22.5        NaN
# 1       42.5        NaN
# 2       62.5        NaN
# 3       82.5        NaN
# 4      102.5        NaN
# 5      122.5        NaN
# 6      142.5        NaN
# 7      162.5        NaN
# 8      182.5        NaN
# 9      202.5        NaN
# 10     222.5        NaN
# 11     242.5        NaN
# 12     262.5        NaN
# 13     282.5        NaN
# 14     302.5        NaN
# 15     322.5        NaN
# 16     342.5        NaN
# 17     362.5        NaN
# 18     382.5        NaN
# 19     402.5        NaN
# 20     422.5        NaN
# 21     442.5        NaN
# 22     462.5        NaN
# 23     482.5        NaN
# 24     502.5        NaN

# %%
df_all = df.append(df_tirs, True)
df_all.sort_values('Distance', inplace=True)
df_all
# Out:
#     Distance  Elevation
# 0        0.0      284.0
# 14      22.5        NaN
# 15      42.5        NaN
# 1       58.0      280.0
# 16      62.5        NaN
# 17      82.5        NaN
# 18     102.5        NaN
# 19     122.5        NaN
# 20     142.5        NaN
# 2      152.0      275.0
# 21     162.5        NaN
# 22     182.5        NaN
# 23     202.5        NaN
# 3      217.0      270.0
# 24     222.5        NaN
# 4      228.0      267.0
# 25     242.5        NaN
# 26     262.5        NaN
# 27     282.5        NaN
# 28     302.5        NaN
# 5      305.0      265.0
# 29     322.5        NaN
# 6      340.0      260.0
# 30     342.5        NaN
# 31     362.5        NaN
# 7      374.0      255.0
# 32     382.5        NaN
# 8      397.0      250.0
# 33     402.5        NaN
# 9      417.0      245.0
# 34     422.5        NaN
# 35     442.5        NaN
# 10     459.0      240.0
# 36     462.5        NaN
# 37     482.5        NaN
# 11     484.0      245.0
# 38     502.5        NaN
# 12     539.0      250.0
# 13     687.0      245.0

# %%
df_all.set_index('Distance', inplace=True)
df_lin=df_all.interpolate(method='slinear')
df_pchip=df_all.interpolate(method='pchip')

# %%
plt.figure(figsize=(12,10))
plt.plot(df['Distance'], df['Elevation'], '-k')
plt.plot(df['Distance'], df['Elevation'], 'or')
plt.plot(df_lin.index, df_lin['Elevation'], 'xg')
plt.plot(df_pchip.index, df_pchip['Elevation'], 'xb')
plt.plot(df_pchip.index, df_pchip['Elevation'], '-b')
plt.legend([' ', 'know_points', 'linear interp.', 'pchip interp.'])

# %% [markdown]
# ## Function to compute y the length of a curve know on some points and approximated by a pchip interpolation

# %%
def cclength(known_points, x_start=0, x_end=1):
    length = 0
    known_points = np.array(known_points)
    x_i = np.array(known_points[0])
    y_i = np.array(known_points[1])
    interp = PchipInterpolator(x_i, y_i)
    poly = PPoly.from_bernstein_basis(interp, extrapolate=None)
    coefs = poly.c
    print(coefs)
    poly_derivative = PPoly.from_bernstein_basis(interp.derivative(), extrapolate=None)
    coefs_derivative = poly_derivative.c
    n_intervals = len (coefs_derivative[0])
    l = []
    f = []
    f_derivative = []
    # create a list of function sqrt(1+(dy/dx)²)
    for i in range(n_intervals):
        f_derivative.append(lambda x : (1+(coefs_derivative[2][i]+coefs_derivative[1][i]*(x-x_i[i])+coefs_derivative[0][i]*(x-x_i[i])**2)**2)**0.5)
        f.append(lambda x : coefs[3][i]+coefs[2][i]*(x-x_i[i])+coefs[1][i]*(x-x_i[i])**2+coefs[0][i]*(x-x_i[i])**3)
        l.append((quad(f_derivative[i], x_i[i], x_i[i+1], epsrel=0.001))[0])
        ui = np.linspace(x_i[i], x_i[i+1], 10)
        vi = poly_derivative(ui)
        plt.plot(ui, vi,'.k')
        print(f_derivative)
        ### for debugging only ###
        print('(1+(',coefs_derivative[2][i], '+', coefs_derivative[1][i], '*(x-xi)+', coefs_derivative[0][i], '*(x-xi)**2)**2)**0.5)')
        print('xi: ', x_i[i], 'xi+1: ', x_i[i+1], 'length: ', (quad(f_derivative[i], x_i[i], x_i[i+1], epsrel=0.001))[0])
        ### print('know_points[0][',i,']: ', known_points[0][i])
        ### print('know_points[0][',i+1,']: ', known_points[0][i+1])
        ### print('length in interval: ', l[i])
        ###                    ###
    # for i in range(n_intervals):
    #     print(f_derivative[0](xi[i]),f_derivative[i](xi[i]))
    return sum(l), l, interp, f

# %% [markdown]
# ## Example of cclength usage

# %%
alpha = np.linspace(np.pi, 0, 150)
xi = np.cos(alpha)
yi = np.sin(alpha)

beta = np.linspace(np.pi, 0, 120)
xn = np.cos(beta)
y0 = np.sin(beta)

# %%
#xi = np.linspace(0, 10, 50)
#yi = (np.exp(xi) + np.exp(-xi))/2

# %%
xi = df['Distance']
yi = df['Elevation']

# %%
interp = PchipInterpolator(xi, yi)
yn = interp(xn)
coefs = PPoly.from_bernstein_basis(interp, extrapolate=False).c

# %%
#plt.plot(xn, y0, '--k', label='True values')
plt.plot(xi, yi, 'ok', label='Known points')
plt.plot(xi, yi, '--k', label='')
#plt.plot(xn, yn, label='pchip')
plt.axis('equal')
plt.legend()
plt.show()

# %%
n_intervals = len(coefs[0])
ff=[]
for i in range(n_intervals):
    def f(j):
        def g(x) : return coefs[3][j]+coefs[2][j]*(x-xi[j])+coefs[1][j]*(x-xi[j])**2+coefs[0][j]*(x-xi[j])**3
        return g(i)
    xx = np.linspace(xi[i], xi[i+1], 10)
    yy = ff[i](xx)
    plt.plot(xx, yy, '-k')
# plt.axis('equal')

# %%
total_length, pieces_length, interp, f =cclength([xi,yi])
# Out:
# [[  6.74149100e-07  -2.02512087e-06  -1.13850094e-05   2.87048918e-03
#    -9.43634498e-06   7.56377969e-05  -2.46227663e-05   4.57517004e-05
#     2.46769146e-04   3.95345661e-05  -4.30163934e-04  -1.67506251e-05
#    -1.54235682e-06]
#  [  6.46758514e-05   2.70011930e-04   5.35029106e-04  -4.37915408e-02
#     1.16558317e-03  -5.35408981e-03   7.74787593e-04  -2.78043794e-03
#    -5.78857902e-03  -4.86436428e-04   1.87540984e-02   1.89676196e-04
#     0.00000000e+00]
#  [ -7.49845542e-02  -6.06786427e-02  -6.35983040e-02  -1.38349515e-01
#    -5.97758406e-02  -4.81203008e-02  -1.44937684e-01  -1.77643881e-01
#    -2.32936078e-01  -1.68356264e-01   0.00000000e+00   1.31147541e-01
#     0.00000000e+00]
#  [  2.84000000e+02   2.80000000e+02   2.75000000e+02   2.70000000e+02
#     2.67000000e+02   2.65000000e+02   2.60000000e+02   2.55000000e+02
#     2.50000000e+02   2.45000000e+02   2.40000000e+02   2.45000000e+02
#     2.50000000e+02]]
# [<function cclength.<locals>.<lambda> at 0x7f25c2ed8d08>]
# (1+( -0.0749845541955 + 0.000129351702806 *(x-xi)+ 2.02244730029e-06 *(x-xi)**2)**2)**0.5)
# xi:  0 xi+1:  58 length:  58.138265946747524
# [<function cclength.<locals>.<lambda> at 0x7f25c2ed8d08>, <function cclength.<locals>.<lambda> at 0x7f25c336abf8>]
# (1+( -0.0606786427146 + 0.000540023859346 *(x-xi)+ -6.07536261987e-06 *(x-xi)**2)**2)**0.5)
# xi:  58 xi+1:  152 length:  94.13366718790253
# [<function cclength.<locals>.<lambda> at 0x7f25c2ed8d08>, <function cclength.<locals>.<lambda> at 0x7f25c336abf8>, <function cclength.<locals>.<lambda> at 0x7f25c3352268>]
# (1+( -0.0635983040452 + 0.00107005821183 *(x-xi)+ -3.41550282335e-05 *(x-xi)**2)**2)**0.5)
# xi:  152 xi+1:  217 length:  65.21070875787626
# [<function cclength.<locals>.<lambda> at 0x7f25c2ed8d08>, <function cclength.<locals>.<lambda> at 0x7f25c336abf8>, <function cclength.<locals>.<lambda> at 0x7f25c3352268>, <function cclength.<locals>.<lambda> at 0x7f25c3352840>]
# (1+( -0.138349514563 + -0.0875830815378 *(x-xi)+ 0.00861146752794 *(x-xi)**2)**2)**0.5)
# xi:  217 xi+1:  228 length:  11.43450416992206
# [<function cclength.<locals>.<lambda> at 0x7f25c2ed8d08>, <function cclength.<locals>.<lambda> at 0x7f25c336abf8>, <function cclength.<locals>.<lambda> at 0x7f25c3352268>, <function cclength.<locals>.<lambda> at 0x7f25c3352840>, <function cclength.<locals>.<lambda> at 0x7f25c3352e18>]
# (1+( -0.0597758405978 + 0.00233116633832 *(x-xi)+ -2.83090349477e-05 *(x-xi)**2)**2)**0.5)
# xi:  228 xi+1:  305 length:  77.03242229204596
# [<function cclength.<locals>.<lambda> at 0x7f25c2ed8d08>, <function cclength.<locals>.<lambda> at 0x7f25c336abf8>, <function cclength.<locals>.<lambda> at 0x7f25c3352268>, <function cclength.<locals>.<lambda> at 0x7f25c3352840>, <function cclength.<locals>.<lambda> at 0x7f25c3352e18>, <function cclength.<locals>.<lambda> at 0x7f25c336c488>]
# (1+( -0.0481203007519 + -0.0107081796154 *(x-xi)+ 0.000226913390607 *(x-xi)**2)**2)**0.5)
# xi:  305 xi+1:  340 length:  35.375987459992
# [<function cclength.<locals>.<lambda> at 0x7f25c2ed8d08>, <function cclength.<locals>.<lambda> at 0x7f25c336abf8>, <function cclength.<locals>.<lambda> at 0x7f25c3352268>, <function cclength.<locals>.<lambda> at 0x7f25c3352840>, <function cclength.<locals>.<lambda> at 0x7f25c3352e18>, <function cclength.<locals>.<lambda> at 0x7f25c336c488>, <function cclength.<locals>.<lambda> at 0x7f25c336ca60>]
# (1+( -0.144937683798 + 0.00154957518603 *(x-xi)+ -7.38682990333e-05 *(x-xi)**2)**2)**0.5)
# xi:  340 xi+1:  374 length:  34.367810825631466
# [<function cclength.<locals>.<lambda> at 0x7f25c2ed8d08>, <function cclength.<locals>.<lambda> at 0x7f25c336abf8>, <function cclength.<locals>.<lambda> at 0x7f25c3352268>, <function cclength.<locals>.<lambda> at 0x7f25c3352840>, <function cclength.<locals>.<lambda> at 0x7f25c3352e18>, <function cclength.<locals>.<lambda> at 0x7f25c336c488>, <function cclength.<locals>.<lambda> at 0x7f25c336ca60>, <function cclength.<locals>.<lambda> at 0x7f25c33650d0>]
# (1+( -0.177643881155 + -0.00556087588927 *(x-xi)+ 0.000137255101327 *(x-xi)**2)**2)**0.5)
# xi:  374 xi+1:  397 length:  23.54026073039659
# [<function cclength.<locals>.<lambda> at 0x7f25c2ed8d08>, <function cclength.<locals>.<lambda> at 0x7f25c336abf8>, <function cclength.<locals>.<lambda> at 0x7f25c3352268>, <function cclength.<locals>.<lambda> at 0x7f25c3352840>, <function cclength.<locals>.<lambda> at 0x7f25c3352e18>, <function cclength.<locals>.<lambda> at 0x7f25c336c488>, <function cclength.<locals>.<lambda> at 0x7f25c336ca60>, <function cclength.<locals>.<lambda> at 0x7f25c33650d0>, <function cclength.<locals>.<lambda> at 0x7f25c33656a8>]
# (1+( -0.232936078007 + -0.011577158041 *(x-xi)+ 0.000740307438123 *(x-xi)**2)**2)**0.5)
# xi:  397 xi+1:  417 length:  20.623204899683625
# [<function cclength.<locals>.<lambda> at 0x7f25c2ed8d08>, <function cclength.<locals>.<lambda> at 0x7f25c336abf8>, <function cclength.<locals>.<lambda> at 0x7f25c3352268>, <function cclength.<locals>.<lambda> at 0x7f25c3352840>, <function cclength.<locals>.<lambda> at 0x7f25c3352e18>, <function cclength.<locals>.<lambda> at 0x7f25c336c488>, <function cclength.<locals>.<lambda> at 0x7f25c336ca60>, <function cclength.<locals>.<lambda> at 0x7f25c33650d0>, <function cclength.<locals>.<lambda> at 0x7f25c33656a8>, <function cclength.<locals>.<lambda> at 0x7f25c3365c80>]
# (1+( -0.168356263577 + -0.000972872856601 *(x-xi)+ 0.00011860369816 *(x-xi)**2)**2)**0.5)
# xi:  417 xi+1:  459 length:  42.35030670976461
# [<function cclength.<locals>.<lambda> at 0x7f25c2ed8d08>, <function cclength.<locals>.<lambda> at 0x7f25c336abf8>, <function cclength.<locals>.<lambda> at 0x7f25c3352268>, <function cclength.<locals>.<lambda> at 0x7f25c3352840>, <function cclength.<locals>.<lambda> at 0x7f25c3352e18>, <function cclength.<locals>.<lambda> at 0x7f25c336c488>, <function cclength.<locals>.<lambda> at 0x7f25c336ca60>, <function cclength.<locals>.<lambda> at 0x7f25c33650d0>, <function cclength.<locals>.<lambda> at 0x7f25c33656a8>, <function cclength.<locals>.<lambda> at 0x7f25c3365c80>, <function cclength.<locals>.<lambda> at 0x7f25c337b2f0>]
# (1+( 0.0 + 0.0375081967213 *(x-xi)+ -0.00129049180328 *(x-xi)**2)**2)**0.5)
# xi:  459 xi+1:  484 length:  25.555223984576454
# [<function cclength.<locals>.<lambda> at 0x7f25c2ed8d08>, <function cclength.<locals>.<lambda> at 0x7f25c336abf8>, <function cclength.<locals>.<lambda> at 0x7f25c3352268>, <function cclength.<locals>.<lambda> at 0x7f25c3352840>, <function cclength.<locals>.<lambda> at 0x7f25c3352e18>, <function cclength.<locals>.<lambda> at 0x7f25c336c488>, <function cclength.<locals>.<lambda> at 0x7f25c336ca60>, <function cclength.<locals>.<lambda> at 0x7f25c33650d0>, <function cclength.<locals>.<lambda> at 0x7f25c33656a8>, <function cclength.<locals>.<lambda> at 0x7f25c3365c80>, <function cclength.<locals>.<lambda> at 0x7f25c337b2f0>, <function cclength.<locals>.<lambda> at 0x7f25c337b8c8>]
# (1+( 0.131147540984 + 0.000379352391275 *(x-xi)+ -5.02518752078e-05 *(x-xi)**2)**2)**0.5)
# xi:  484 xi+1:  539 length:  55.269297591993286
# [<function cclength.<locals>.<lambda> at 0x7f25c2ed8d08>, <function cclength.<locals>.<lambda> at 0x7f25c336abf8>, <function cclength.<locals>.<lambda> at 0x7f25c3352268>, <function cclength.<locals>.<lambda> at 0x7f25c3352840>, <function cclength.<locals>.<lambda> at 0x7f25c3352e18>, <function cclength.<locals>.<lambda> at 0x7f25c336c488>, <function cclength.<locals>.<lambda> at 0x7f25c336ca60>, <function cclength.<locals>.<lambda> at 0x7f25c33650d0>, <function cclength.<locals>.<lambda> at 0x7f25c33656a8>, <function cclength.<locals>.<lambda> at 0x7f25c3365c80>, <function cclength.<locals>.<lambda> at 0x7f25c337b2f0>, <function cclength.<locals>.<lambda> at 0x7f25c337b8c8>, <function cclength.<locals>.<lambda> at 0x7f25c337bea0>]
# (1+( 0.0 + 0.0 *(x-xi)+ -4.6270704598e-06 *(x-xi)**2)**2)**0.5)
# xi:  539 xi+1:  687 length:  148.15181090055017

# %%
for i in range(len(f)):
    xi = np.linspace(0,900,100)
    yi = f[i](xi)
    plt.plot(xi,yi, '-g')

# %%
total_length
# Out:
# 691.1834714570825

# %%
def binsearch(a,x):
    """ searches where to insert a value x in an ordered list a """
    return min(len(a)-2,max(0, bisect_left(a, x)-1))

# %%
def x_from_d_along_curve(known_points=[xi,yi], distance=2):
    total_length, pieces_length, interp, f =cclength(known_points)
    cl = list(np.cumsum(pieces_length))
    i = binsearch(cl, distance)
    print(i)
    print(known_points[0][i], ': ', cl[i], ' - ', known_points[0][i+1], ': ', cl[i+1])
    print('elevation: ',f[i]())
    x = fminbound(lambda x: distance-f[i](x-known_points[0][i]), known_points[0][i], known_points[1][i+1])
    return x

# %%
x_from_d_along_curve(known_points=[xi, yi], distance=2)
# Out:
# [[  4.62661657e-06   4.62614669e-06   4.62611387e-06   4.62607926e-06
#     4.62604274e-06   4.62600417e-06   4.62596339e-06   4.62592021e-06
#     4.62587447e-06   4.62582593e-06   4.62577439e-06   4.62571957e-06
#     4.62566120e-06   4.62559896e-06   4.62553251e-06   4.62546145e-06
#     4.62538535e-06   4.62530372e-06   4.62521601e-06   4.62512160e-06
#     4.62501979e-06   4.62490979e-06   4.62479070e-06   4.62466148e-06
#     4.62452096e-06   4.62436777e-06   4.62420034e-06   4.62401686e-06
#     4.62381520e-06   4.62359288e-06   4.62334698e-06   4.62307403e-06
#     4.62276994e-06   4.62242976e-06   4.62204755e-06   4.62161608e-06
#     4.62112653e-06   4.62056796e-06   4.61992676e-06   4.61918578e-06
#     4.61832320e-06   4.61731085e-06   4.61611192e-06   4.61467756e-06
#     4.61294179e-06   4.61081378e-06   4.60816567e-06   4.60481288e-06
#     4.60048095e-06   4.59474728e-06   4.58693362e-06   4.57589479e-06
#     4.55957115e-06   4.53394573e-06   4.49028957e-06   4.40652045e-06
#     4.21229942e-06   3.57836587e-06   1.60043270e-07  -9.09554061e-07
#     2.31181539e-06   3.95268723e-06   4.31676869e-06   4.44916742e-06
#     4.51174747e-06   4.54623909e-06   4.56726430e-06   4.58102722e-06
#     4.59052790e-06   4.59736205e-06   4.60244241e-06   4.60632192e-06
#     4.60935146e-06   4.61176249e-06   4.61371267e-06   4.61531243e-06
#     4.61664100e-06   4.61775641e-06   4.61870194e-06   4.61951042e-06
#     4.62020713e-06   4.62081177e-06   4.62133986e-06   4.62180382e-06
#     4.62221362e-06   4.62257738e-06   4.62290175e-06   4.62319221e-06
# [<function cclength.<locals>.<lambda> at 0x7f25c320ec80>, <function cclength.<locals>.<lambda> at 0x7f25c2ff6158>, <function cclength.<locals>.<lambda> at 0x7f25c2ff6730>, <function cclength.<locals>.<lambda> at 0x7f25c2ff6d08>, <function cclength.<locals>.<lambda> at 0x7f25c2ffc378>, <function cclength.<locals>.<lambda> at 0x7f25c2ffc950>, <function cclength.<locals>.<lambda> at 0x7f25c3005048>, <function cclength.<locals>.<lambda> at 0x7f25c3005598>, <function cclength.<locals>.<lambda> at 0x7f25c3005b70>, <function cclength.<locals>.<lambda> at 0x7f25c300c1e0>, <function cclength.<locals>.<lambda> at 0x7f25c300c7b8>, <function cclength.<locals>.<lambda> at 0x7f25c300cd90>, <function cclength.<locals>.<lambda> at 0x7f25c2f94400>, <function cclength.<locals>.<lambda> at 0x7f25c2f949d8>, <function cclength.<locals>.<lambda> at 0x7f25c2f9d0d0>, <function cclength.<locals>.<lambda> at 0x7f25c2f9d620>, <function cclength.<locals>.<lambda> at 0x7f25c2f9dbf8>, <function cclength.<locals>.<lambda> at 0x7f25c2fa5268>, <function cclength.<locals>.<lambda> at 0x7f25c2fa5840>, <function cclength.<locals>.<lambda> at 0x7f25c2fa5e18>, <function cclength.<locals>.<lambda> at 0x7f25c2fad488>, <function cclength.<locals>.<lambda> at 0x7f25c2fada60>, <function cclength.<locals>.<lambda> at 0x7f25c2fb40d0>, <function cclength.<locals>.<lambda> at 0x7f25c2fb46a8>, <function cclength.<locals>.<lambda> at 0x7f25c2fb4c80>, <function cclength.<locals>.<lambda> at 0x7f25c2fbc2f0>, <function cclength.<locals>.<lambda> at 0x7f25c2fbc8c8>, <function cclength.<locals>.<lambda> at 0x7f25c2fbcea0>]
# (1+( -0.398454915732 + 0.00254833630241 *(x-xi)+ 1.38720505684e-05 *(x-xi)**2)**2)**0.5)
# xi:  245.454545455 xi+1:  254.545454545 length:  9.74644219610635
# [<function cclength.<locals>.<lambda> at 0x7f25c320ec80>, <function cclength.<locals>.<lambda> at 0x7f25c2ff6158>, <function cclength.<locals>.<lambda> at 0x7f25c2ff6730>, <function cclength.<locals>.<lambda> at 0x7f25c2ff6d08>, <function cclength.<locals>.<lambda> at 0x7f25c2ffc378>, <function cclength.<locals>.<lambda> at 0x7f25c2ffc950>, <function cclength.<locals>.<lambda> at 0x7f25c3005048>, <function cclength.<locals>.<lambda> at 0x7f25c3005598>, <function cclength.<locals>.<lambda> at 0x7f25c3005b70>, <function cclength.<locals>.<lambda> at 0x7f25c300c1e0>, <function cclength.<locals>.<lambda> at 0x7f25c300c7b8>, <function cclength.<locals>.<lambda> at 0x7f25c300cd90>, <function cclength.<locals>.<lambda> at 0x7f25c2f94400>, <function cclength.<locals>.<lambda> at 0x7f25c2f949d8>, <function cclength.<locals>.<lambda> at 0x7f25c2f9d0d0>, <function cclength.<locals>.<lambda> at 0x7f25c2f9d620>, <function cclength.<locals>.<lambda> at 0x7f25c2f9dbf8>, <function cclength.<locals>.<lambda> at 0x7f25c2fa5268>, <function cclength.<locals>.<lambda> at 0x7f25c2fa5840>, <function cclength.<locals>.<lambda> at 0x7f25c2fa5e18>, <function cclength.<locals>.<lambda> at 0x7f25c2fad488>, <function cclength.<locals>.<lambda> at 0x7f25c2fada60>, <function cclength.<locals>.<lambda> at 0x7f25c2fb40d0>, <function cclength.<locals>.<lambda> at 0x7f25c2fb46a8>, <function cclength.<locals>.<lambda> at 0x7f25c2fb4c80>, <function cclength.<locals>.<lambda> at 0x7f25c2fbc2f0>, <function cclength.<locals>.<lambda> at 0x7f25c2fbc8c8>, <function cclength.<locals>.<lambda> at 0x7f25c2fbcea0>, <function cclength.<locals>.<lambda> at 0x7f25c2fc5510>]
# (1+( -0.374141771613 + 0.00246421316059 *(x-xi)+ 1.38714455895e-05 *(x-xi)**2)**2)**0.5)
# xi:  254.545454545 xi+1:  263.636363636 length:  9.670136528831431
# [<function cclength.<locals>.<lambda> at 0x7f25c320ec80>, <function cclength.<locals>.<lambda> at 0x7f25c2ff6158>, <function cclength.<locals>.<lambda> at 0x7f25c2ff6730>, <function cclength.<locals>.<lambda> at 0x7f25c2ff6d08>, <function cclength.<locals>.<lambda> at 0x7f25c2ffc378>, <function cclength.<locals>.<lambda> at 0x7f25c2ffc950>, <function cclength.<locals>.<lambda> at 0x7f25c3005048>, <function cclength.<locals>.<lambda> at 0x7f25c3005598>, <function cclength.<locals>.<lambda> at 0x7f25c3005b70>, <function cclength.<locals>.<lambda> at 0x7f25c300c1e0>, <function cclength.<locals>.<lambda> at 0x7f25c300c7b8>, <function cclength.<locals>.<lambda> at 0x7f25c300cd90>, <function cclength.<locals>.<lambda> at 0x7f25c2f94400>, <function cclength.<locals>.<lambda> at 0x7f25c2f949d8>, <function cclength.<locals>.<lambda> at 0x7f25c2f9d0d0>, <function cclength.<locals>.<lambda> at 0x7f25c2f9d620>, <function cclength.<locals>.<lambda> at 0x7f25c2f9dbf8>, <function cclength.<locals>.<lambda> at 0x7f25c2fa5268>, <function cclength.<locals>.<lambda> at 0x7f25c2fa5840>, <function cclength.<locals>.<lambda> at 0x7f25c2fa5e18>, <function cclength.<locals>.<lambda> at 0x7f25c2fad488>, <function cclength.<locals>.<lambda> at 0x7f25c2fada60>, <function cclength.<locals>.<lambda> at 0x7f25c2fb40d0>, <function cclength.<locals>.<lambda> at 0x7f25c2fb46a8>, <function cclength.<locals>.<lambda> at 0x7f25c2fb4c80>, <function cclength.<locals>.<lambda> at 0x7f25c2fbc2f0>, <function cclength.<locals>.<lambda> at 0x7f25c2fbc8c8>, <function cclength.<locals>.<lambda> at 0x7f25c2fbcea0>, <function cclength.<locals>.<lambda> at 0x7f25c2fc5510>, <function cclength.<locals>.<lambda> at 0x7f25c2fc5ae8>]
# (1+( -0.350593433328 + 0.00238009057004 *(x-xi)+ 1.38707786305e-05 *(x-xi)**2)**2)**0.5)
# xi:  263.636363636 xi+1:  272.727272727 length:  9.600388336869472
# [<function cclength.<locals>.<lambda> at 0x7f25c320ec80>, <function cclength.<locals>.<lambda> at 0x7f25c2ff6158>, <function cclength.<locals>.<lambda> at 0x7f25c2ff6730>, <function cclength.<locals>.<lambda> at 0x7f25c2ff6d08>, <function cclength.<locals>.<lambda> at 0x7f25c2ffc378>, <function cclength.<locals>.<lambda> at 0x7f25c2ffc950>, <function cclength.<locals>.<lambda> at 0x7f25c3005048>, <function cclength.<locals>.<lambda> at 0x7f25c3005598>, <function cclength.<locals>.<lambda> at 0x7f25c3005b70>, <function cclength.<locals>.<lambda> at 0x7f25c300c1e0>, <function cclength.<locals>.<lambda> at 0x7f25c300c7b8>, <function cclength.<locals>.<lambda> at 0x7f25c300cd90>, <function cclength.<locals>.<lambda> at 0x7f25c2f94400>, <function cclength.<locals>.<lambda> at 0x7f25c2f949d8>, <function cclength.<locals>.<lambda> at 0x7f25c2f9d0d0>, <function cclength.<locals>.<lambda> at 0x7f25c2f9d620>, <function cclength.<locals>.<lambda> at 0x7f25c2f9dbf8>, <function cclength.<locals>.<lambda> at 0x7f25c2fa5268>, <function cclength.<locals>.<lambda> at 0x7f25c2fa5840>, <function cclength.<locals>.<lambda> at 0x7f25c2fa5e18>, <function cclength.<locals>.<lambda> at 0x7f25c2fad488>, <function cclength.<locals>.<lambda> at 0x7f25c2fada60>, <function cclength.<locals>.<lambda> at 0x7f25c2fb40d0>, <function cclength.<locals>.<lambda> at 0x7f25c2fb46a8>, <function cclength.<locals>.<lambda> at 0x7f25c2fb4c80>, <function cclength.<locals>.<lambda> at 0x7f25c2fbc2f0>, <function cclength.<locals>.<lambda> at 0x7f25c2fbc8c8>, <function cclength.<locals>.<lambda> at 0x7f25c2fbcea0>, <function cclength.<locals>.<lambda> at 0x7f25c2fc5510>, <function cclength.<locals>.<lambda> at 0x7f25c2fc5ae8>, <function cclength.<locals>.<lambda> at 0x7f25c2fce158>]
# (1+( -0.327809900986 + 0.00229596860825 *(x-xi)+ 1.38700409261e-05 *(x-xi)**2)**2)**0.5)
# xi:  272.727272727 xi+1:  281.818181818 length:  9.536880942393312
# [<function cclength.<locals>.<lambda> at 0x7f25c320ec80>, <function cclength.<locals>.<lambda> at 0x7f25c2ff6158>, <function cclength.<locals>.<lambda> at 0x7f25c2ff6730>, <function cclength.<locals>.<lambda> at 0x7f25c2ff6d08>, <function cclength.<locals>.<lambda> at 0x7f25c2ffc378>, <function cclength.<locals>.<lambda> at 0x7f25c2ffc950>, <function cclength.<locals>.<lambda> at 0x7f25c3005048>, <function cclength.<locals>.<lambda> at 0x7f25c3005598>, <function cclength.<locals>.<lambda> at 0x7f25c3005b70>, <function cclength.<locals>.<lambda> at 0x7f25c300c1e0>, <function cclength.<locals>.<lambda> at 0x7f25c300c7b8>, <function cclength.<locals>.<lambda> at 0x7f25c300cd90>, <function cclength.<locals>.<lambda> at 0x7f25c2f94400>, <function cclength.<locals>.<lambda> at 0x7f25c2f949d8>, <function cclength.<locals>.<lambda> at 0x7f25c2f9d0d0>, <function cclength.<locals>.<lambda> at 0x7f25c2f9d620>, <function cclength.<locals>.<lambda> at 0x7f25c2f9dbf8>, <function cclength.<locals>.<lambda> at 0x7f25c2fa5268>, <function cclength.<locals>.<lambda> at 0x7f25c2fa5840>, <function cclength.<locals>.<lambda> at 0x7f25c2fa5e18>, <function cclength.<locals>.<lambda> at 0x7f25c2fad488>, <function cclength.<locals>.<lambda> at 0x7f25c2fada60>, <function cclength.<locals>.<lambda> at 0x7f25c2fb40d0>, <function cclength.<locals>.<lambda> at 0x7f25c2fb46a8>, <function cclength.<locals>.<lambda> at 0x7f25c2fb4c80>, <function cclength.<locals>.<lambda> at 0x7f25c2fbc2f0>, <function cclength.<locals>.<lambda> at 0x7f25c2fbc8c8>, <function cclength.<locals>.<lambda> at 0x7f25c2fbcea0>, <function cclength.<locals>.<lambda> at 0x7f25c2fc5510>, <function cclength.<locals>.<lambda> at 0x7f25c2fc5ae8>, <function cclength.<locals>.<lambda> at 0x7f25c2fce158>, <function cclength.<locals>.<lambda> at 0x7f25c2fce730>]
# (1+( -0.305791174719 + 0.00221184736684 *(x-xi)+ 1.38692221037e-05 *(x-xi)**2)**2)**0.5)
# xi:  281.818181818 xi+1:  290.909090909 length:  9.47929172612549
# [<function cclength.<locals>.<lambda> at 0x7f25c320ec80>, <function cclength.<locals>.<lambda> at 0x7f25c2ff6158>, <function cclength.<locals>.<lambda> at 0x7f25c2ff6730>, <function cclength.<locals>.<lambda> at 0x7f25c2ff6d08>, <function cclength.<locals>.<lambda> at 0x7f25c2ffc378>, <function cclength.<locals>.<lambda> at 0x7f25c2ffc950>, <function cclength.<locals>.<lambda> at 0x7f25c3005048>, <function cclength.<locals>.<lambda> at 0x7f25c3005598>, <function cclength.<locals>.<lambda> at 0x7f25c3005b70>, <function cclength.<locals>.<lambda> at 0x7f25c300c1e0>, <function cclength.<locals>.<lambda> at 0x7f25c300c7b8>, <function cclength.<locals>.<lambda> at 0x7f25c300cd90>, <function cclength.<locals>.<lambda> at 0x7f25c2f94400>, <function cclength.<locals>.<lambda> at 0x7f25c2f949d8>, <function cclength.<locals>.<lambda> at 0x7f25c2f9d0d0>, <function cclength.<locals>.<lambda> at 0x7f25c2f9d620>, <function cclength.<locals>.<lambda> at 0x7f25c2f9dbf8>, <function cclength.<locals>.<lambda> at 0x7f25c2fa5268>, <function cclength.<locals>.<lambda> at 0x7f25c2fa5840>, <function cclength.<locals>.<lambda> at 0x7f25c2fa5e18>, <function cclength.<locals>.<lambda> at 0x7f25c2fad488>, <function cclength.<locals>.<lambda> at 0x7f25c2fada60>, <function cclength.<locals>.<lambda> at 0x7f25c2fb40d0>, <function cclength.<locals>.<lambda> at 0x7f25c2fb46a8>, <function cclength.<locals>.<lambda> at 0x7f25c2fb4c80>, <function cclength.<locals>.<lambda> at 0x7f25c2fbc2f0>, <function cclength.<locals>.<lambda> at 0x7f25c2fbc8c8>, <function cclength.<locals>.<lambda> at 0x7f25c2fbcea0>, <function cclength.<locals>.<lambda> at 0x7f25c2fc5510>, <function cclength.<locals>.<lambda> at 0x7f25c2fc5ae8>, <function cclength.<locals>.<lambda> at 0x7f25c2fce158>, <function cclength.<locals>.<lambda> at 0x7f25c2fce730>, <function cclength.<locals>.<lambda> at 0x7f25c2fced08>]
# (1+( -0.284537254681 + 0.00212772695477 *(x-xi)+ 1.38683098143e-05 *(x-xi)**2)**2)**0.5)
# xi:  290.909090909 xi+1:  300.0 length:  9.427294006072032
# [<function cclength.<locals>.<lambda> at 0x7f25c320ec80>, <function cclength.<locals>.<lambda> at 0x7f25c2ff6158>, <function cclength.<locals>.<lambda> at 0x7f25c2ff6730>, <function cclength.<locals>.<lambda> at 0x7f25c2ff6d08>, <function cclength.<locals>.<lambda> at 0x7f25c2ffc378>, <function cclength.<locals>.<lambda> at 0x7f25c2ffc950>, <function cclength.<locals>.<lambda> at 0x7f25c3005048>, <function cclength.<locals>.<lambda> at 0x7f25c3005598>, <function cclength.<locals>.<lambda> at 0x7f25c3005b70>, <function cclength.<locals>.<lambda> at 0x7f25c300c1e0>, <function cclength.<locals>.<lambda> at 0x7f25c300c7b8>, <function cclength.<locals>.<lambda> at 0x7f25c300cd90>, <function cclength.<locals>.<lambda> at 0x7f25c2f94400>, <function cclength.<locals>.<lambda> at 0x7f25c2f949d8>, <function cclength.<locals>.<lambda> at 0x7f25c2f9d0d0>, <function cclength.<locals>.<lambda> at 0x7f25c2f9d620>, <function cclength.<locals>.<lambda> at 0x7f25c2f9dbf8>, <function cclength.<locals>.<lambda> at 0x7f25c2fa5268>, <function cclength.<locals>.<lambda> at 0x7f25c2fa5840>, <function cclength.<locals>.<lambda> at 0x7f25c2fa5e18>, <function cclength.<locals>.<lambda> at 0x7f25c2fad488>, <function cclength.<locals>.<lambda> at 0x7f25c2fada60>, <function cclength.<locals>.<lambda> at 0x7f25c2fb40d0>, <function cclength.<locals>.<lambda> at 0x7f25c2fb46a8>, <function cclength.<locals>.<lambda> at 0x7f25c2fb4c80>, <function cclength.<locals>.<lambda> at 0x7f25c2fbc2f0>, <function cclength.<locals>.<lambda> at 0x7f25c2fbc8c8>, <function cclength.<locals>.<lambda> at 0x7f25c2fbcea0>, <function cclength.<locals>.<lambda> at 0x7f25c2fc5510>, <function cclength.<locals>.<lambda> at 0x7f25c2fc5ae8>, <function cclength.<locals>.<lambda> at 0x7f25c2fce158>, <function cclength.<locals>.<lambda> at 0x7f25c2fce730>, <function cclength.<locals>.<lambda> at 0x7f25c2fced08>, <function cclength.<locals>.<lambda> at 0x7f25c2f56378>]
# (1+( -0.264048141058 + 0.00204360750237 *(x-xi)+ 1.38672892709e-05 *(x-xi)**2)**2)**0.5)
# xi:  300.0 xi+1:  309.090909091 length:  9.380558915674143
# ...
# (1+( -0.487386422881 + -0.00317242299013 *(x-xi)+ 1.387415118e-05 *(x-xi)**2)**2)**0.5)
# xi:  863.636363636 xi+1:  872.727272727 length:  10.169950184760816
# [<function cclength.<locals>.<lambda> at 0x7f25c320ec80>, <function cclength.<locals>.<lambda> at 0x7f25c2ff6158>, <function cclength.<locals>.<lambda> at 0x7f25c2ff6730>, <function cclength.<locals>.<lambda> at 0x7f25c2ff6d08>, <function cclength.<locals>.<lambda> at 0x7f25c2ffc378>, <function cclength.<locals>.<lambda> at 0x7f25c2ffc950>, <function cclength.<locals>.<lambda> at 0x7f25c3005048>, <function cclength.<locals>.<lambda> at 0x7f25c3005598>, <function cclength.<locals>.<lambda> at 0x7f25c3005b70>, <function cclength.<locals>.<lambda> at 0x7f25c300c1e0>, <function cclength.<locals>.<lambda> at 0x7f25c300c7b8>, <function cclength.<locals>.<lambda> at 0x7f25c300cd90>, <function cclength.<locals>.<lambda> at 0x7f25c2f94400>, <function cclength.<locals>.<lambda> at 0x7f25c2f949d8>, <function cclength.<locals>.<lambda> at 0x7f25c2f9d0d0>, <function cclength.<locals>.<lambda> at 0x7f25c2f9d620>, <function cclength.<locals>.<lambda> at 0x7f25c2f9dbf8>, <function cclength.<locals>.<lambda> at 0x7f25c2fa5268>, <function cclength.<locals>.<lambda> at 0x7f25c2fa5840>, <function cclength.<locals>.<lambda> at 0x7f25c2fa5e18>, <function cclength.<locals>.<lambda> at 0x7f25c2fad488>, <function cclength.<locals>.<lambda> at 0x7f25c2fada60>, <function cclength.<locals>.<lambda> at 0x7f25c2fb40d0>, <function cclength.<locals>.<lambda> at 0x7f25c2fb46a8>, <function cclength.<locals>.<lambda> at 0x7f25c2fb4c80>, <function cclength.<locals>.<lambda> at 0x7f25c2fbc2f0>, <function cclength.<locals>.<lambda> at 0x7f25c2fbc8c8>, <function cclength.<locals>.<lambda> at 0x7f25c2fbcea0>, <function cclength.<locals>.<lambda> at 0x7f25c2fc5510>, <function cclength.<locals>.<lambda> at 0x7f25c2fc5ae8>, <function cclength.<locals>.<lambda> at 0x7f25c2fce158>, <function cclength.<locals>.<lambda> at 0x7f25c2fce730>, <function cclength.<locals>.<lambda> at 0x7f25c2fced08>, <function cclength.<locals>.<lambda> at 0x7f25c2f56378>, <function cclength.<locals>.<lambda> at 0x7f25c2f56950>, <function cclength.<locals>.<lambda> at 0x7f25c2f5d048>, <function cclength.<locals>.<lambda> at 0x7f25c33ead08>, <function cclength.<locals>.<lambda> at 0x7f25c31db1e0>, <function cclength.<locals>.<lambda> at 0x7f25c2f5d8c8>, <function cclength.<locals>.<lambda> at 0x7f25c2f5dea0>, <function cclength.<locals>.<lambda> at 0x7f25c2f66510>, <function cclength.<locals>.<lambda> at 0x7f25c2f66ae8>, <function cclength.<locals>.<lambda> at 0x7f25c2f6e158>, <function cclength.<locals>.<lambda> at 0x7f25c2f6e730>, <function cclength.<locals>.<lambda> at 0x7f25c2f6ed08>, <function cclength.<locals>.<lambda> at 0x7f25c2f76378>, <function cclength.<locals>.<lambda> at 0x7f25c2f76950>, <function cclength.<locals>.<lambda> at 0x7f25c2f7f048>, <function cclength.<locals>.<lambda> at 0x7f25c2f7f598>, <function cclength.<locals>.<lambda> at 0x7f25c2f7fb70>, <function cclength.<locals>.<lambda> at 0x7f25c2f871e0>, <function cclength.<locals>.<lambda> at 0x7f25c2f877b8>, <function cclength.<locals>.<lambda> at 0x7f25c2f87d90>, <function cclength.<locals>.<lambda> at 0x7f25c2f8f400>, <function cclength.<locals>.<lambda> at 0x7f25c2f8f9d8>, <function cclength.<locals>.<lambda> at 0x7f25c2f180d0>, <function cclength.<locals>.<lambda> at 0x7f25c2f18620>, <function cclength.<locals>.<lambda> at 0x7f25c2f18bf8>, <function cclength.<locals>.<lambda> at 0x7f25c2f1f268>, <function cclength.<locals>.<lambda> at 0x7f25c2f1f840>, <function cclength.<locals>.<lambda> at 0x7f25c2f1fe18>, <function cclength.<locals>.<lambda> at 0x7f25c2f28488>, <function cclength.<locals>.<lambda> at 0x7f25c2f28a60>, <function cclength.<locals>.<lambda> at 0x7f25c2f300d0>, <function cclength.<locals>.<lambda> at 0x7f25c2f306a8>, <function cclength.<locals>.<lambda> at 0x7f25c2f30c80>, <function cclength.<locals>.<lambda> at 0x7f25c2f382f0>, <function cclength.<locals>.<lambda> at 0x7f25c2f388c8>, <function cclength.<locals>.<lambda> at 0x7f25c2f38ea0>, <function cclength.<locals>.<lambda> at 0x7f25c2f41510>, <function ...
# (1+( -0.515080007818 + -0.00325655499476 *(x-xi)+ 1.38745256725e-05 *(x-xi)**2)**2)**0.5)
# xi:  872.727272727 xi+1:  881.818181818 length:  10.286890089240014
# [<function cclength.<locals>.<lambda> at 0x7f25c320ec80>, <function cclength.<locals>.<lambda> at 0x7f25c2ff6158>, <function cclength.<locals>.<lambda> at 0x7f25c2ff6730>, <function cclength.<locals>.<lambda> at 0x7f25c2ff6d08>, <function cclength.<locals>.<lambda> at 0x7f25c2ffc378>, <function cclength.<locals>.<lambda> at 0x7f25c2ffc950>, <function cclength.<locals>.<lambda> at 0x7f25c3005048>, <function cclength.<locals>.<lambda> at 0x7f25c3005598>, <function cclength.<locals>.<lambda> at 0x7f25c3005b70>, <function cclength.<locals>.<lambda> at 0x7f25c300c1e0>, <function cclength.<locals>.<lambda> at 0x7f25c300c7b8>, <function cclength.<locals>.<lambda> at 0x7f25c300cd90>, <function cclength.<locals>.<lambda> at 0x7f25c2f94400>, <function cclength.<locals>.<lambda> at 0x7f25c2f949d8>, <function cclength.<locals>.<lambda> at 0x7f25c2f9d0d0>, <function cclength.<locals>.<lambda> at 0x7f25c2f9d620>, <function cclength.<locals>.<lambda> at 0x7f25c2f9dbf8>, <function cclength.<locals>.<lambda> at 0x7f25c2fa5268>, <function cclength.<locals>.<lambda> at 0x7f25c2fa5840>, <function cclength.<locals>.<lambda> at 0x7f25c2fa5e18>, <function cclength.<locals>.<lambda> at 0x7f25c2fad488>, <function cclength.<locals>.<lambda> at 0x7f25c2fada60>, <function cclength.<locals>.<lambda> at 0x7f25c2fb40d0>, <function cclength.<locals>.<lambda> at 0x7f25c2fb46a8>, <function cclength.<locals>.<lambda> at 0x7f25c2fb4c80>, <function cclength.<locals>.<lambda> at 0x7f25c2fbc2f0>, <function cclength.<locals>.<lambda> at 0x7f25c2fbc8c8>, <function cclength.<locals>.<lambda> at 0x7f25c2fbcea0>, <function cclength.<locals>.<lambda> at 0x7f25c2fc5510>, <function cclength.<locals>.<lambda> at 0x7f25c2fc5ae8>, <function cclength.<locals>.<lambda> at 0x7f25c2fce158>, <function cclength.<locals>.<lambda> at 0x7f25c2fce730>, <function cclength.<locals>.<lambda> at 0x7f25c2fced08>, <function cclength.<locals>.<lambda> at 0x7f25c2f56378>, <function cclength.<locals>.<lambda> at 0x7f25c2f56950>, <function cclength.<locals>.<lambda> at 0x7f25c2f5d048>, <function cclength.<locals>.<lambda> at 0x7f25c33ead08>, <function cclength.<locals>.<lambda> at 0x7f25c31db1e0>, <function cclength.<locals>.<lambda> at 0x7f25c2f5d8c8>, <function cclength.<locals>.<lambda> at 0x7f25c2f5dea0>, <function cclength.<locals>.<lambda> at 0x7f25c2f66510>, <function cclength.<locals>.<lambda> at 0x7f25c2f66ae8>, <function cclength.<locals>.<lambda> at 0x7f25c2f6e158>, <function cclength.<locals>.<lambda> at 0x7f25c2f6e730>, <function cclength.<locals>.<lambda> at 0x7f25c2f6ed08>, <function cclength.<locals>.<lambda> at 0x7f25c2f76378>, <function cclength.<locals>.<lambda> at 0x7f25c2f76950>, <function cclength.<locals>.<lambda> at 0x7f25c2f7f048>, <function cclength.<locals>.<lambda> at 0x7f25c2f7f598>, <function cclength.<locals>.<lambda> at 0x7f25c2f7fb70>, <function cclength.<locals>.<lambda> at 0x7f25c2f871e0>, <function cclength.<locals>.<lambda> at 0x7f25c2f877b8>, <function cclength.<locals>.<lambda> at 0x7f25c2f87d90>, <function cclength.<locals>.<lambda> at 0x7f25c2f8f400>, <function cclength.<locals>.<lambda> at 0x7f25c2f8f9d8>, <function cclength.<locals>.<lambda> at 0x7f25c2f180d0>, <function cclength.<locals>.<lambda> at 0x7f25c2f18620>, <function cclength.<locals>.<lambda> at 0x7f25c2f18bf8>, <function cclength.<locals>.<lambda> at 0x7f25c2f1f268>, <function cclength.<locals>.<lambda> at 0x7f25c2f1f840>, <function cclength.<locals>.<lambda> at 0x7f25c2f1fe18>, <function cclength.<locals>.<lambda> at 0x7f25c2f28488>, <function cclength.<locals>.<lambda> at 0x7f25c2f28a60>, <function cclength.<locals>.<lambda> at 0x7f25c2f300d0>, <function cclength.<locals>.<lambda> at 0x7f25c2f306a8>, <function cclength.<locals>.<lambda> at 0x7f25c2f30c80>, <function cclength.<locals>.<lambda> at 0x7f25c2f382f0>, <function cclength.<locals>.<lambda> at 0x7f25c2f388c8>, <function cclength.<locals>.<lambda> at 0x7f25c2f38ea0>, <function cclength.<locals>.<lambda> at 0x7f25c2f41510>, <function ...
# (1+( -0.543538398211 + -0.00334068673078 *(x-xi)+ 1.38748711367e-05 *(x-xi)**2)**2)**0.5)
# xi:  881.818181818 xi+1:  890.909090909 length:  10.412163341593917
# [<function cclength.<locals>.<lambda> at 0x7f25c320ec80>, <function cclength.<locals>.<lambda> at 0x7f25c2ff6158>, <function cclength.<locals>.<lambda> at 0x7f25c2ff6730>, <function cclength.<locals>.<lambda> at 0x7f25c2ff6d08>, <function cclength.<locals>.<lambda> at 0x7f25c2ffc378>, <function cclength.<locals>.<lambda> at 0x7f25c2ffc950>, <function cclength.<locals>.<lambda> at 0x7f25c3005048>, <function cclength.<locals>.<lambda> at 0x7f25c3005598>, <function cclength.<locals>.<lambda> at 0x7f25c3005b70>, <function cclength.<locals>.<lambda> at 0x7f25c300c1e0>, <function cclength.<locals>.<lambda> at 0x7f25c300c7b8>, <function cclength.<locals>.<lambda> at 0x7f25c300cd90>, <function cclength.<locals>.<lambda> at 0x7f25c2f94400>, <function cclength.<locals>.<lambda> at 0x7f25c2f949d8>, <function cclength.<locals>.<lambda> at 0x7f25c2f9d0d0>, <function cclength.<locals>.<lambda> at 0x7f25c2f9d620>, <function cclength.<locals>.<lambda> at 0x7f25c2f9dbf8>, <function cclength.<locals>.<lambda> at 0x7f25c2fa5268>, <function cclength.<locals>.<lambda> at 0x7f25c2fa5840>, <function cclength.<locals>.<lambda> at 0x7f25c2fa5e18>, <function cclength.<locals>.<lambda> at 0x7f25c2fad488>, <function cclength.<locals>.<lambda> at 0x7f25c2fada60>, <function cclength.<locals>.<lambda> at 0x7f25c2fb40d0>, <function cclength.<locals>.<lambda> at 0x7f25c2fb46a8>, <function cclength.<locals>.<lambda> at 0x7f25c2fb4c80>, <function cclength.<locals>.<lambda> at 0x7f25c2fbc2f0>, <function cclength.<locals>.<lambda> at 0x7f25c2fbc8c8>, <function cclength.<locals>.<lambda> at 0x7f25c2fbcea0>, <function cclength.<locals>.<lambda> at 0x7f25c2fc5510>, <function cclength.<locals>.<lambda> at 0x7f25c2fc5ae8>, <function cclength.<locals>.<lambda> at 0x7f25c2fce158>, <function cclength.<locals>.<lambda> at 0x7f25c2fce730>, <function cclength.<locals>.<lambda> at 0x7f25c2fced08>, <function cclength.<locals>.<lambda> at 0x7f25c2f56378>, <function cclength.<locals>.<lambda> at 0x7f25c2f56950>, <function cclength.<locals>.<lambda> at 0x7f25c2f5d048>, <function cclength.<locals>.<lambda> at 0x7f25c33ead08>, <function cclength.<locals>.<lambda> at 0x7f25c31db1e0>, <function cclength.<locals>.<lambda> at 0x7f25c2f5d8c8>, <function cclength.<locals>.<lambda> at 0x7f25c2f5dea0>, <function cclength.<locals>.<lambda> at 0x7f25c2f66510>, <function cclength.<locals>.<lambda> at 0x7f25c2f66ae8>, <function cclength.<locals>.<lambda> at 0x7f25c2f6e158>, <function cclength.<locals>.<lambda> at 0x7f25c2f6e730>, <function cclength.<locals>.<lambda> at 0x7f25c2f6ed08>, <function cclength.<locals>.<lambda> at 0x7f25c2f76378>, <function cclength.<locals>.<lambda> at 0x7f25c2f76950>, <function cclength.<locals>.<lambda> at 0x7f25c2f7f048>, <function cclength.<locals>.<lambda> at 0x7f25c2f7f598>, <function cclength.<locals>.<lambda> at 0x7f25c2f7fb70>, <function cclength.<locals>.<lambda> at 0x7f25c2f871e0>, <function cclength.<locals>.<lambda> at 0x7f25c2f877b8>, <function cclength.<locals>.<lambda> at 0x7f25c2f87d90>, <function cclength.<locals>.<lambda> at 0x7f25c2f8f400>, <function cclength.<locals>.<lambda> at 0x7f25c2f8f9d8>, <function cclength.<locals>.<lambda> at 0x7f25c2f180d0>, <function cclength.<locals>.<lambda> at 0x7f25c2f18620>, <function cclength.<locals>.<lambda> at 0x7f25c2f18bf8>, <function cclength.<locals>.<lambda> at 0x7f25c2f1f268>, <function cclength.<locals>.<lambda> at 0x7f25c2f1f840>, <function cclength.<locals>.<lambda> at 0x7f25c2f1fe18>, <function cclength.<locals>.<lambda> at 0x7f25c2f28488>, <function cclength.<locals>.<lambda> at 0x7f25c2f28a60>, <function cclength.<locals>.<lambda> at 0x7f25c2f300d0>, <function cclength.<locals>.<lambda> at 0x7f25c2f306a8>, <function cclength.<locals>.<lambda> at 0x7f25c2f30c80>, <function cclength.<locals>.<lambda> at 0x7f25c2f382f0>, <function cclength.<locals>.<lambda> at 0x7f25c2f388c8>, <function cclength.<locals>.<lambda> at 0x7f25c2f38ea0>, <function cclength.<locals>.<lambda> at 0x7f25c2f41510>, <function ...
# (1+( -0.572761594016 + -0.00342483600532 *(x-xi)+ 1.38781241906e-05 *(x-xi)**2)**2)**0.5)
# xi:  890.909090909 xi+1:  900.0 length:  10.545991515361523
# 0
# 0.0 :  15.0673266487  -  9.09090909091 :  29.8134899091

# %%
xs = 1
b=1
c=0
d=0
g = lambda x : (1+(b+c*(x-xs)+d*(x-xs)**2)**2)**0.5
l = quad(g, 0, 1)[0]
l
# Out:
# 1.4142135623730954

# %%
xi = np.linspace(0,2,20)
yi = g(xi)

# %%
plt.plot(xi, yi, '.k')

# %% [markdown]
# # Essai de découpage des fonctions

# %%
t=np.linspace(np.pi, 0, 17)
x = np.cos(t)
y = np.sin(t)
known_points=[x.tolist(), y.tolist()]

# %%
plt.plot(known_points[0], known_points[1])

# %%
def pchip_coefs(known_points, x_start=0, x_end=1):
    known_points = np.array(known_points).T
    x_i = np.array(known_points[0])
    y_i = np.array(known_points[1])
    interp = PchipInterpolator(x_i, y_i)
    poly = PPoly.from_bernstein_basis(interp, extrapolate=None)
    coefs = poly.c
    return coefs

# %%
coefs=pchip_coefs(known_points)
coefs
# Out:
# array([[  6.74149100e-07,  -2.02512087e-06,  -1.13850094e-05,
#           2.87048918e-03,  -9.43634498e-06,   7.56377969e-05,
#          -2.46227663e-05,   4.57517004e-05,   2.46769146e-04,
#           3.95345661e-05,  -4.30163934e-04,  -1.67506251e-05,
#          -1.54235682e-06],
#        [  6.46758514e-05,   2.70011930e-04,   5.35029106e-04,
#          -4.37915408e-02,   1.16558317e-03,  -5.35408981e-03,
#           7.74787593e-04,  -2.78043794e-03,  -5.78857902e-03,
#          -4.86436428e-04,   1.87540984e-02,   1.89676196e-04,
#           0.00000000e+00],
#        [ -7.49845542e-02,  -6.06786427e-02,  -6.35983040e-02,
#          -1.38349515e-01,  -5.97758406e-02,  -4.81203008e-02,
#          -1.44937684e-01,  -1.77643881e-01,  -2.32936078e-01,
#          -1.68356264e-01,   0.00000000e+00,   1.31147541e-01,
#           0.00000000e+00],
#        [  2.84000000e+02,   2.80000000e+02,   2.75000000e+02,
#           2.70000000e+02,   2.67000000e+02,   2.65000000e+02,
#           2.60000000e+02,   2.55000000e+02,   2.50000000e+02,
#           2.45000000e+02,   2.40000000e+02,   2.45000000e+02,
#           2.50000000e+02]])

# %%
def cclength(coefs, x_start=0.0, x_end=1.0):
    G = lambda x : (1+(coefs[2]+2*coefs[1]*(x)+3*coefs[0]*(x)**2)**2)**0.5
    l = quad(G, 0, x_end-x_start, epsrel=0.001)
    return l[0]

# %%
f_list = []
for i in range(len(coefs.T)):
    
    def f(j): # to avoid problems due to lexical closures
        def func(x): return coefs[3][j]+coefs[2][j]*x+coefs[1][j]*(x)**2+coefs[0][j]*(x)**3
        return func
    f_list.append(f(i))

# %%
l=[]
ll=[]
for i in range(len(known_points[0])-1):
    t = np.linspace(0,known_points[0][i+1]-known_points[0][i],101)
    u = f_list[i](t)
    l.append(cclength(coefs.T[i],known_points[0][i],known_points[0][i+1]))
    plt.plot(known_points[0][i]+t, u, '-k')
    ll.append(((known_points[0][i+1]-known_points[0][i])**2+(known_points[1][i+1]-known_points[1][i])**2)**0.5)
plt.axis('equal')
lt=np.cumsum(np.array(l))
llt=np.cumsum(np.array(ll))
print(lt, llt)
# Out:
# [ 284.49352962] [ 360.47191291]

# %%
def cclength2abs(coefs, x_start, length, x_tol=1e-05):
    from scipy.optimize import root
    F = lambda x : length - cclength(coefs, x_start, x)
    x = root(F, x_start)
    return x.x

# %%
cclength2abs(coefs.T[0],0,0.1)
# Out:
# array([ 0.09972009])

# %%
def cclength2xz(known_points, distances):
    known_points = np.array(known_points).T
    np.array(distances.sort())
    print(known_points)
    x_i = np.array(known_points[0])
    y_i = np.array(known_points[1])
    print(x_i, y_i)
    interp = PchipInterpolator(x_i, y_i)
    poly = PPoly.from_bernstein_basis(interp, extrapolate=None)
    coefs = poly.c.T
    szd = len(distances)
    szj = len(coefs)
    print(coefs)
    print('szj=', szj)
    l = []
    for j in range(szj):
        l.append(cclength(coefs[j], 0, x_i[j+1]-x_i[j]))
    l = np.cumsum(np.array(l))
    print(l)
    i = 0
    j = 0
    xz = np.array([[np.nan, np.nan]]*szd)
    while (i<szd):
        if distances[i]<=l[j]:
            xz[i,0] = cclength2abs(coefs[j], 0, distances[i])
            xz[i,0] = xz[i,0] + x_i[j]
            xz[i,1] = interp(xz[i,0])
            print('i=', i, 'd=', distances[i])
            i+=1
        elif j<szj:
            distances = distances - l[j]
            j+=1
            print('j=', j)
        else:
            print('out of range')
            break
    return xz

# %%
np.array(known_points[0])
# Out:
# array([  0, 284])

# %%
xz = cclength2xz(known_points, np.linspace(0,500,21))
xz
# Out:
# [[  0  58 152 217 228 305 340 374 397 417 459 484 539 687]
#  [284 280 275 270 267 265 260 255 250 245 240 245 250 245]]
# [  0  58 152 217 228 305 340 374 397 417 459 484 539 687] [284 280 275 270 267 265 260 255 250 245 240 245 250 245]
# [[  6.74149100e-07   6.46758514e-05  -7.49845542e-02   2.84000000e+02]
#  [ -2.02512087e-06   2.70011930e-04  -6.06786427e-02   2.80000000e+02]
#  [ -1.13850094e-05   5.35029106e-04  -6.35983040e-02   2.75000000e+02]
#  [  2.87048918e-03  -4.37915408e-02  -1.38349515e-01   2.70000000e+02]
#  [ -9.43634498e-06   1.16558317e-03  -5.97758406e-02   2.67000000e+02]
#  [  7.56377969e-05  -5.35408981e-03  -4.81203008e-02   2.65000000e+02]
#  [ -2.46227663e-05   7.74787593e-04  -1.44937684e-01   2.60000000e+02]
#  [  4.57517004e-05  -2.78043794e-03  -1.77643881e-01   2.55000000e+02]
#  [  2.46769146e-04  -5.78857902e-03  -2.32936078e-01   2.50000000e+02]
#  [  3.95345661e-05  -4.86436428e-04  -1.68356264e-01   2.45000000e+02]
#  [ -4.30163934e-04   1.87540984e-02   0.00000000e+00   2.40000000e+02]
#  [ -1.67506251e-05   1.89676196e-04   1.31147541e-01   2.45000000e+02]
#  [ -1.54235682e-06   0.00000000e+00   0.00000000e+00   2.50000000e+02]]
# szj= 13
# [  58.13826595  152.27193313  217.48264189  228.91714606  305.94956835
#   341.32555581  375.69336664  399.23362737  419.85683227  462.20713898
#   487.76236296  543.03166056  691.18347146]
# i= 0 d= 0.0
# i= 1 d= 25.0
# i= 2 d= 50.0
# j= 1
# i= 3 d= 16.8617340533
# i= 4 d= 41.8617340533
# i= 5 d= 66.8617340533
# i= 6 d= 91.8617340533
# i= 7 d= 116.861734053
# i= 8 d= 141.861734053
# j= 2
# i= 9 d= 14.5898009186
# i= 10 d= 39.5898009186
# i= 11 d= 64.5898009186
# i= 12 d= 89.5898009186
# i= 13 d= 114.589800919
# i= 14 d= 139.589800919
# i= 15 d= 164.589800919
# i= 16 d= 189.589800919
# i= 17 d= 214.589800919
# j= 3
# i= 18 d= 22.1071590261
# i= 19 d= 47.1071590261
# i= 20 d= 72.1071590261
# array([[   0.        ,  284.        ],
#        [  24.93371716,  282.1810147 ],
#        [  49.87738991,  280.50451399],
#        [  74.83465026,  279.04535721],
#        [  99.80295624,  277.78736039],
#        [ 124.77227206,  276.54931531],
#        [ 149.73255179,  275.14268156],
#        [ 174.66998669,  273.70055002],
#        [ 199.56293314,  271.9604294 ],
#        [ 166.56509234,  274.15200877],
#        [ 191.51766635,  272.6196709 ],
#        [ 216.38486469,  270.08446871],
#        [ 240.96177301,  266.40047661],
#        [ 264.85788599,  265.90774533],
#        [ 287.5597013 ,  265.58080255],
#        [ 308.62473365,  264.75883317],
#        [ 327.84503852,  262.00822195],
#        [ 345.25065365,  259.2567785 ],
#        [ 236.69834901,  266.56202806],
#        [ 245.1919564 ,  266.26889102],
#        [ 249.88303327,  266.1511987 ]])

# %%
plt.plot(xz.T[0], xz.T[1], 'ow')
