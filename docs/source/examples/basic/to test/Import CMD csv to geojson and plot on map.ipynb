# %% [markdown]
# # Import a GF Instruments CMD csv file, convert it to geojson and plot on a map
#
# O. Kaufmann, 2018

# %%
import os
import pandas as pd
import folium
import geojson
import json
import numpy as np
from osgeo import ogr # osgeo is in pygdal package

# %%
pwd
# Out:
# '/home/su530201/PycharmProjects/stage-geophy/donnees_fournies/exemples_notebooks_python'

# %%
home_dir = '../sample_data/'
#filename = '/home/su530201/PycharmProjects/stage-geophy/traitement/example_notebooks/sample_data/'
#filename = 'CMD_UTM31N.dat'
filename = 'CMD_WGS84.dat'
zoom_start = 15

# %% [markdown]
# ###  ** If geographic coordinates are given, WGS84 crs is assumed otherwise EPSG:32631 is assumed**

# %%
input_crs_epsg = 32631  # WGS84 UTM 31N
output_crs_epsg = 4326  # WGS84

in_crs = ogr.osr.SpatialReference()
in_crs.ImportFromEPSG(input_crs_epsg)

out_crs = ogr.osr.SpatialReference()
out_crs.ImportFromEPSG(output_crs_epsg)

crs_transform = ogr.osr.CoordinateTransformation(in_crs, out_crs)

# %% [markdown]
# ### Convert degrees minutes to decimal degrees

# %%
def ddmm_to_dd(x):
    degrees = float(x) // 100
    minutes = x - 100 * degrees
    return degrees + minutes/60

# %%
df= pd.read_csv(home_dir + filename, sep='\t')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-9d3838fad0e7> in <module>
# ----> 1 df= pd.read_csv(home_dir + filename, sep='\t')
#
# ~/.local/share/virtualenvs/stage-geophy-FGdLp7ag/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/.local/share/virtualenvs/stage-geophy-FGdLp7ag/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~/.local/share/virtualenvs/stage-geophy-FGdLp7ag/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~/.local/share/virtualenvs/stage-geophy-FGdLp7ag/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~/.local/share/virtualenvs/stage-geophy-FGdLp7ag/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File ../sample_data/CMD_WGS84.dat does not exist: '../sample_data/CMD_WGS84.dat'

# %%
if ('Latitude' in df.columns) and ('Longitude' in df.columns):
    df['Latitude']=pd.to_numeric(df['Latitude'].str.rstrip('N'), errors='ignore').map(lambda x: ddmm_to_dd(x))
    df['Longitude']=pd.to_numeric(df['Longitude'].str.rstrip('E'), errors='ignore').map(lambda x: ddmm_to_dd(x))
    WGS84_input = True
elif ('Easting' in df.columns) and ('Northing' in df.columns):
    WGS84_input = False
else:
    WGS84_input = None
    print('### Unexpected dataframe format! ###')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-30ad6fecde42> in <module>
# ----> 1 if ('Latitude' in df.columns) and ('Longitude' in df.columns):
#       2     df['Latitude']=pd.to_numeric(df['Latitude'].str.rstrip('N'), errors='ignore').map(lambda x: ddmm_to_dd(x))
#       3     df['Longitude']=pd.to_numeric(df['Longitude'].str.rstrip('E'), errors='ignore').map(lambda x: ddmm_to_dd(x))
#       4     WGS84_input = True
#       5 elif ('Easting' in df.columns) and ('Northing' in df.columns):
#
# NameError: name 'df' is not defined

# %%
df
# Out:
#       Latitude  Longitude  Altitude         Time  Cond.1[mS/m]  Inph.1[ppt]  \
# 0    50.140167   5.181265     164.5  07:43:55.36         13.11         1.70
# 1    50.140168   5.181267     164.5  07:43:55.77         13.09         1.69
# 2    50.140170   5.181270     164.5  07:43:56.36         13.50         1.69
# 3    50.140170   5.181270     164.5  07:43:56.81         13.55         1.69
# 559         19.35         3.89         20.46         2.96             20.97
# 560         19.46         3.93         20.57         3.09             21.08
# 561         19.66         3.92         20.54         2.99             21.05
# 562         19.16         3.95         20.29         2.93             25.86
# 563         19.37         3.95         20.43         2.99             20.94
# 564         19.37         3.86         20.67         3.00             15.28
# 565         19.67         3.92         20.58         2.90             21.09
# 566         19.35         3.96         20.34         3.02             20.85
# 567         19.71         3.98         20.62         2.96             21.13
# 568         19.43         3.92         20.41         3.05             20.92
# 569         19.24         3.99         20.31         3.05             20.71
# 570         19.58         3.93         20.46         3.02             20.97
# 571         19.55         3.95         20.58         2.98             21.09
# 572         19.45         3.93         20.44         3.07             20.95
#
#      Inv.Cond.2[mS/m]  Inv.Thick [m]  Inv.RMS[%]  Note
# 0                7.00            0.7         4.0   NaN
# 1                6.89            0.7         3.1   NaN
# 2                7.12            0.7         3.6   NaN
# 3                6.90            0.7         3.6   NaN
# 4                6.69            0.2         3.9   NaN
# 5                6.86            0.7         4.0   NaN
# 6                5.18            1.4         2.9   NaN
# 7                6.98            0.7         2.7   NaN
# 8                6.80            0.7         3.8   NaN
# 9                5.14            1.4         3.2   NaN
# 10               6.39            0.2         4.3   NaN
# 11               6.31            0.2         3.3   NaN
# 12               5.09            1.4         2.3   NaN
# 13               4.98            1.4         2.0   NaN
# 14               6.31            0.2         3.5   NaN
# 15               6.16            0.2         2.9   NaN
# 16               4.93            1.4         2.1   NaN
# 17               5.99            0.2         1.7   NaN
# 18               5.79            0.2         1.6   NaN
# 19               5.91            0.2         3.0   NaN
# 20               5.79            0.2         1.6   NaN
# 21               5.67            0.2         2.4   NaN
# 22               5.80            0.2         1.9   NaN
# 23               5.68            0.2         2.3   NaN
# 24               5.71            0.2         2.5   NaN
# 25               5.72            0.2         3.1   NaN
# 26               5.66            0.2         4.2   NaN
# 27               5.79            0.2         3.2   NaN
# 28               4.72            1.4         2.4   NaN
# 29               4.64            1.4         2.4   NaN
# ..                ...            ...         ...   ...
# 543             17.70            0.6         8.1   NaN
# 544             17.47            0.6         7.0   NaN
# 545             14.57            3.3         2.9   NaN
# 546             17.09            2.1         3.0   NaN
# 547             17.11            2.1         3.1   NaN
# 548             17.26            2.1         2.5   NaN
# 549             17.04            2.1         3.7   NaN
# 550             17.09            2.1         3.4   NaN
# 551             17.13            2.1         3.1   NaN
# 552             17.21            2.1         2.6   NaN
# 553             17.27            2.1         3.3   NaN
# 554             17.00            2.1         2.7   NaN
# 555             14.45            3.3         3.6   NaN
# 556             17.09            2.1         4.6   NaN
# 557             17.07            2.1         4.4   NaN
# 558             14.55            3.3         3.7   NaN
# 559             17.10            2.1         4.5   NaN
# 560             17.19            2.1         4.5   NaN
# 561             17.17            2.1         4.3   NaN
# 562             16.72            0.4         8.4   NaN
# 563             17.07            2.1         4.6   NaN
# 564             23.44            3.0         6.3   NaN
# 565             17.20            2.1         4.0   NaN
# 566             17.01            2.1         3.7   NaN
# 567             17.24            2.1         3.9   NaN
# 568             17.06            2.1         3.8   NaN
# 569             14.57            3.3         4.0   NaN
# 570             17.10            2.1         4.0   NaN
# 571             17.20            2.1         4.4   NaN
# 572             17.09            2.1         4.1   NaN
#
# [573 rows x 15 columns]

# %% [markdown]
# ### Filter dataframe: remove rows without position

# %%
if WGS84_input:
    df = df[df['Latitude'].notnull()]
elif not WGS84_input:
    df = df[df['Northing'].notnull()]
    df.loc[:,'Latitude'] = pd.Series(np.nan, index=df.index)
    df.loc[:,'Longitude'] = pd.Series(np.nan, index=df.index)

# %% [markdown]
# ## Reproject if needed and save data to a geojson file
# ### *TODO: Add properties to the geojson file...*

# %%
stations = []

# %%
for idx, row in df.iterrows():
    # properties = {}
    # for col in df.columns:
    #    properties[col]=row[col]
    # print(properties)
    if WGS84_input:
        station_location = geojson.Point((row['Longitude'], row['Latitude'], row['Altitude']))
    if not WGS84_input:
        station_location = geojson.Point((row['Easting'], row['Northing'], row['Altitude']))
        point = ogr.CreateGeometryFromJson(str(station_location))
        point.Transform(crs_transform)
        station_location = point.ExportToJson()
        station_location = geojson.loads(station_location)
        df.set_value(idx, 'Latitude', station_location['coordinates'][1])
        df.set_value(idx, 'Longitude', station_location['coordinates'][0])
    station = geojson.Feature(geometry=station_location, properties={'id': str(idx), 'time': str(row['Time']), 'C1': row['Cond.1[mS/m]']})
    stations.append(station)
stations_geojson = geojson.FeatureCollection(stations)

# %%
stations_geojson
# Out:
# {"features": [{"geometry": {"coordinates": [5.181265, 50.140166666666666, 164.5], "type": "Point"}, "properties": {"C1": 13.11, "id": "0", "time": "07:43:55.36"}, "type": "Feature"}, {"geometry": {"coordinates": [5.181266666666667, 50.140168333333335, 164.5], "type": "Point"}, "properties": {"C1": 13.09, "id": "1", "time": "07:43:55.77"}, "type": "Feature"}, {"geometry": {"coordinates": [5.18127, 50.140170000000005, 164.5], "type": "Point"}, "properties": {"C1": 13.5, "id": "2", "time": "07:43:56.36"}, "type": "Feature"}, {"geometry": {"coordinates": [5.18127, 50.140170000000005, 164.5], "type": "Point"}, "properties": {"C1": 13.55, "id": "3", "time": "07:43:56.81"}, "type": "Feature"}, {"geometry": {"coordinates": [5.18127, 50.14018333333333, 164.9], "type": "Point"}, "properties": {"C1": 13.78, "id": "4", "time": "07:43:57.43"}, "type": "Feature"}, {"geometry": {"coordinates": [5.18127, 50.14018333333333, 164.9], "type": "Point"}, "properties": {"C1": 13.74, "id": "5", "time": "07:43:57.95"}, "type": "Feature"}, {"geometry": {"coordinates": [5.18127, 50.14019166666667, 164.8], "type": "Point"}, "properties": {"C1": 13.59, "id": "6", "time": "07:43:58.29"}, "type": "Feature"}, {"geometry": {"coordinates": [5.18127, 50.14019166666667, 164.8], "type": "Point"}, "properties": {"C1": 13.4, "id": "7", "time": "07:43:58.81"}, "type": "Feature"}, {"geometry": {"coordinates": [5.181273333333333, 50.140193333333336, 165.1], "type": "Point"}, "properties": {"C1": 13.35, "id": "8", "time": "07:43:59.40"}, "type": "Feature"}, {"geometry": {"coordinates": [5.181273333333333, 50.140193333333336, 165.1], "type": "Point"}, "properties": {"C1": 13.46, "id": "9", "time": "07:43:59.85"}, "type": "Feature"}, {"geometry": {"coordinates": [5.181276666666666, 50.14019666666666, 165.3], "type": "Point"}, "properties": {"C1": 13.52, "id": "10", "time": "07:44:00.43"}, "type": "Feature"}, {"geometry": {"coordinates": [5.181276666666666, 50.14019666666666, 165.3], "type": "Point"}, "properties": {"C1": 13.23, "id": "11", "time": "07:44:00.96"}, "type": "Feature"}, {"geometry": {"coordinates": [5.181281666666666, 50.14019833333334, 165.5], "type": "Point"}, "properties": {"C1": 13.09, "id": "12", "time": "07:44:01.31"}, "type": "Feature"}, {"geometry": {"coordinates": [5.181281666666666, 50.14019833333334, 165.5], "type": "Point"}, "properties": {"C1": 12.92, "id": "13", "time": "07:44:01.83"}, "type": "Feature"}, {"geometry": {"coordinates": [5.181288333333333, 50.14019499999999, 165.8], "type": "Point"}, "properties": {"C1": 13.26, "id": "14", "time": "07:44:02.43"}, "type": "Feature"}, {"geometry": {"coordinates": [5.
}, "type": "Feature"}, {"geometry": {"coordinates": [5.181288333333333, 50.14019499999999, 165.8], "type": "Point"}, "properties": {"C1": 13.13, "id": "15", "time": "07:44:02.88"}, "type": "Feature"}, {"geometry": {"coordinates": [5.181295, 50.14018833333333, 166.1], "type": "Point"}, "properties": {"C1": 12.88, "id": "16", "time": "07:44:03.27"}, "type": "Feature"}, {"geometry": {"coordinates": [5.181295, 50.14018833333333, 166.1], "type": "Point"}, "properties": {"C1": 13.15, "id": "17", "time": "07:44:03.80"}, "type": "Feature"}, {"geometry": {"coordinates": [5.181303333333333, 50.14018166666666, 166.3], "type": "Point"}, "properties": {"C1": 12.65, "id": "18", "time": "07:44:04.32"}, "type": "Feature"}, {"geometry": {"coordinates": [5.181303333333333, 50.14018166666666, 166.3], "type": "Point"}, "properties": {"C1": 12.45, "id": "19", "time": "07:44:04.85"}, "type": "Feature"}, {"geometry": {"coordinates": [5.181303333333333, 50.140179999999994, 166.3], "type": "Point"}, "properties": {"C1": 12.7, "id": "20", "time": "07:44:05.44"}, "type": "Feature"}, {"geometry": {"coordinates": [5.181303333333333, 50.140179999999994, 166.3], "type": "Point"}, "properties": {"C1": 12.52, "id": "21", "time": "07:44:05.89"}, "type": "Feature"}, {"geometry": {"coordinates": [5.181305, 50.140179999999994, 166.3], "type": "Point"}, "properties": {"C1": 12.78, "id": "22", "time": "07:44:06.31"}, "type": "Fea ...

# %% [markdown]
# ### Flip coordinates in geojson
# #### This is needed with geographic coordinates because leaflet uses the Latitude, Longitude, Altitude order while geojson format is Longitude, Latitude, Altitude

# %%
def flip_geojson_coordinates(geo):
    if isinstance(geo, dict):
        for k, v in geo.items():
            if k == 'coordinates':
                z = np.array(geo[k])
                f = z.flatten()
                geo[k] = np.dstack((f[1::2], f[::2])).reshape(z.shape).tolist()
            else:
                print(k,v)
    elif isinstance(geo, list):
        for k in geo:
            flip_geojson_coordinates(k)

# %%
flip_geojson_coordinates(stations_geojson)
stations_geojson
# Out:
# features [{"geometry": {"coordinates": [5.181265, 50.140166666666666, 164.5], "type": "Point"}, "properties": {"C1": 13.11, "id": "0", "time": "07:43:55.36"}, "type": "Feature"}, {"geometry": {"coordinates": [5.181266666666667, 50.140168333333335, 164.5], "type": "Point"}, "properties": {"C1": 13.09, "id": "1", "time": "07:43:55.77"}, "type": "Feature"}, {"geometry": {"coordinates": [5.18127, 50.140170000000005, 164.5], "type": "Point"}, "properties": {"C1": 13.5, "id": "2", "time": "07:43:56.36"}, "type": "Feature"}, {"geometry": {"coordinates": [5.18127, 50.140170000000005, 164.5], "type": "Point"}, "properties": {"C1": 13.55, "id": "3", "time": "07:43:56.81"}, "type": "Feature"}, {"geometry": {"coordinates": [5.18127, 50.14018333333333, 164.9], "type": "Point"}, "properties": {"C1": 13.78, "id": "4", "time": "07:43:57.43"}, "type": "Feature"}, {"geometry": {"coordinates": [5.18127, 50.14018333333333, 164.9], "type": "Point"}, "properties": {"C1": 13.74, "id": "5", "time": "07:43:57.95"}, "type": "Feature"}, {"geometry": {"coordinates": [5.18127, 50.14019166666667, 164.8], "type": "Point"}, "properties": {"C1": 13.59, "id": "6", "time": "07:43:58.29"}, "type": "Feature"}, {"geometry": {"coordinates": [5.18127, 50.14019166666667, 164.8], "type": "Point"}, "properties": {"C1": 13.4, "id": "7", "time": "07:43:58.81"}, "type": "Feature"}, {"geometry": {"coordinates": [5.181273333333333, 50.140193333333336, 165.1], "type": "Point"}, "properties": {"C1": 13.35, "id": "8", "time": "07:43:59.40"}, "type": "Feature"}, {"geometry": {"coordinates": [5.181273333333333, 50.140193333333336, 165.1], "type": "Point"}, "properties": {"C1": 13.46, "id": "9", "time": "07:43:59.85"}, "type": "Feature"}, {"geometry": {"coordinates": [5.181276666666666, 50.14019666666666, 165.3], "type": "Point"}, "properties": {"C1": 13.52, "id": "10", "time": "07:44:00.43"}, "type": "Feature"}, {"geometry": {"coordinates": [5.181276666666666, 50.14019666666666, 165.3], "type": "Point"}, "properties": {"C1": 13.23, "id": "11", "time": "07:44:00.96"}, "type": "Feature"}, {"geometry": {"coordinates": [5.181281666666666, 50.14019833333334, 165.5], "type": "Point"}, "properties": {"C1": 13.09, "id": "12", "time": "07:44:01.31"}, "type": "Feature"}, {"geometry": {"coordinates": [5.
}, "type": "Feature"}, {"geometry": {"coordinates": [5.181295, 50.14018833333333, 166.1], "type": "Point"}, "properties": {"C1": 12.88, "id": "16", "time": "07:44:03.27"}, "type": "Feature"}, {"geometry": {"coordinates": [5.181295, 50.14018833333333, 166.1], "type": "Point"}, "properties": {"C1": 13.15, "id": "17", "time": "07:44:03.80"}, "type": "Feature"}, {"geometry": {"coordinates": [5.181303333333333, 50.14018166666666, 166.3], "type": "Point"}, "properties": {"C1": 12.65, "id": "18", "time": "07:44:04.32"}, "type": "Feature"}, {"geometry": {"coordinates": [5.181303333333333, 50.14018166666666, 166.3], "type": "Point"}, "properties": {"C1": 12.45, "id": "19", "time": "07:44:04.85"}, "type": "Feature"}, {"geometry": {"coordinates": [5.181303333333333, 50.140179999999994, 166.3], "type": "Point"}, "properties": {"C1": 12.7, "id": "20", "time": "07:44:05.44"}, "type": "Feature"}, {"geometry": {"coordinates": [5.181303333333333, 50.140179999999994, 166.3], "type": "Point"}, "properties": {"C1": 12.52, "id": "21", "time": "07:44:05.89"}, "type": "Feature"}, {"geometry": {"coordinates": [5.181305, 50.140179999999994, 166.3], "type": "Point"}, "properties": {"C1": 12.78, "id": "22", "time": "07:44:06.31"}, "type": "Fea ...

# %% [markdown]
# ## Plot the map

# %% [markdown]
# ### Define the basemap and add markers from positions store

# %%
center = [np.mean([i['geometry']['coordinates'][0] for i in stations_geojson.features]), np.mean([i['geometry']['coordinates'][1] for i in stations_geojson.features])]
print(center)
map_osm = folium.Map(location=center, zoom_start=zoom_start, control_scale=True)
for i in stations_geojson.features:
    #print(i)
    folium.CircleMarker(location=[i['geometry']['coordinates'][0], i['geometry']['coordinates'][1]], popup=str(i['properties']['id']), radius=0.75, color='#dd2222', fill_color='#dd2222').add_to(map_osm)
# Out:
# [5.182611509598604, 50.13900993891798]

# %% [markdown]
# ### Import a geojson file

# %%
with open(home_dir + '2017-03-26_08-50_Sun.geojson') as f:
    geojson_dataset =  json.load(f)
# flip_geojson_coordinates(geojson_dataset)
folium.GeoJson(geojson_dataset,name='geojson').add_to(map_osm)

# %% [markdown]
# ### Display map

# %%
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import branca

# %%
field = 'Cond.1[mS/m]'
min_val = df[field].min()
max_val = df[field].max()

# %%
cm = branca.colormap.LinearColormap(['green', 'yellow', 'red'], vmin=min_val, vmax=max_val, caption=field )

# %%
f = folium.map.FeatureGroup()

for idx, row in df.iterrows():
    f.add_child(
        folium.CircleMarker(location=[row['Latitude'], row['Longitude']], 
                            popup='hello', 
                            radius=row[field],
                            color=None, 
                            fill_color=cm(row[field]),
                            fill_opacity=0.6)
    )

# %%
m = folium.Map(location=center, zoom_start=zoom_start, control_scale=True)
m.add_child(f)
m.add_child(cm)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
cm
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#008000;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#018100;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#028100;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#038200;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#048200;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#058300;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#068300;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#078400;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#088400;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#098500;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#0a8500;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#0b8600;stroke-width:3;" /><line x1="12" y1="0" x2="12" y2="20" style="stroke:#0c8600;stroke-width:3;" /><line x1="13" y1="0" x2="13" y2="20" style="stroke:#0d8700;stroke-width:3;" /><line x1="14" y1="0" x2="14" y2="20" style="stroke:#0e8700;stroke-width:3;" /><line x1="15" y1="0" x2="15" y2="20" style="stroke:#0f8800;stroke-width:3;" /><line x1="16" y1="0" x2="16" y2="20" style="stroke:#108800;stroke-width:3;" /><line x1="17" y1="0" x2="17" y2="20" style="stroke:#118900;stroke-width:3;" /><line x1="18" y1="0" x2="18" y2="20" style="stroke:#128900;stroke-width:3;" /><line x1="19" y1="0" x2="19" y2="20" style="stroke:#138a00;stroke-width:3;" /><line x1="20" y1="0" x2="20" y2="20" style="stroke:#148a00;stroke-width:3;" /><line x1="21" y1="0" x2="21" y2="20" style="stroke:#158b00;stroke-width:3;" /><line x1="22" y1="0" x2="22" y2="20" style="stroke:#168b00;stroke-width:3;" /><line x1="23" y1="0" x2="23" y2="20" style="stroke:#178c00;stroke-width:3;" /><line x1="24" y1="0" x2="24" y2="20" style="stroke:#188c00;stroke-width:3;" /><line x1="25" y1="0" x2="25" y2="20" style="stroke:#198d00;stroke-width:3;" /><line x1="26" y1="0" x2="26" y2="20" style="stroke:#1a8d00;stroke-width:3;" /><line x1="27" y1="0" x2="27" y2="20" style="stroke:#1b8e00;stroke-width:3;" /><line x1="28" y1="0" x2="28" y2="20" style="stroke:#1c8e00;stroke-width:3;" /><line x1="29" y1="0" x2="29" y2="20" style="stroke:#1d8f00;stroke-width:3;" /><line x1="30" y1="0" x2="30" y2="20" style="stroke:#1e8f00;stroke-width:3;" /><line x1="31" y1="0" x2="31" y2="20" style="stroke:#1f9000;stroke-width:3;" /><line x1="32" y1="0" x2="32" y2="20" style="stroke:#209000;stroke-width:3;" /><line x1="33" y1="0" x2="33" y2="20" style="stroke:#219100;stroke-width:3;" /><line x1="34" y1="0" x2="34" y2="20" style="stroke:#229100;stroke-width:3;" /><line x1="35" y1="0" x2="35" y2="20" style="stroke:#239200;stroke-width:3;" /><line x1="36" y1="0" x2="36" y2="20" style="stroke:#249200;stroke-width:3;" /><line x1="37" y1="0" x2="37" y2="20" style="stroke:#259300;stroke-width:3;" /><line x1="38" y1="0" x2="38" y2="20" style="stroke:#269300;stroke-width:3;" /><line x1="39" y1="0" x2="39" y2="20" style="stroke:#289400;stroke-width:3;" /><line x1="40" y1="0" x2="40" y2="20" style="stroke:#299400;stroke-width:3;" /><line x1="41" y1="0" x2="41" y2="20" style="stroke:#2a9500;stroke-width:3;" /><line x1="42" y1="0" x2="42" y2="20" style="stroke:#2b9500;stroke-width:3;" /><line x1="43" y1="0" x2="43" y2="20" style="stroke:#2c9600;stroke-width:3;" /><line x1="44" y1="0" x2="44" y2="20" style="stroke:#2d9600;stroke-width:3;" /><line x1="45" y1="0" x2="45" y2="20" style="stroke:#2e9700;stroke-width:3;" /><line x1="46" y1="0" x2="46" y2="20" style="stroke:#2f9800;stroke-width:3;" /><line x1="47" y1="0" x2="47" y2="20" style="stroke:#309800;stroke-width:3;" /><line x1="48" y1="0" x2="48" y2="20" style="stroke:#319900;stroke-width:3;" /><line x1="49" y1="0" x2="49" y2="20" style="stroke:#329900;stroke-width:3;" /><line x1="50" y1="0" x2="50" y2="20" style="stroke:#339a00;stroke-width:3;" /><line x1="51" ...
